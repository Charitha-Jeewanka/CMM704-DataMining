# %%
from PIL import Image
import os

folder = r"D:\MSc\CMM704 Data Mining\Coursework\data\Q1\raw\diabetic-retinopathy-detection\test"

sizes = []

for file in os.listdir(folder):
    if file.endswith((".jpg", ".jpeg", ".png")):
        img = Image.open(os.path.join(folder, file))
        sizes.append(img.size)

print("Unique resolutions:", set(sizes))
# Out:
# Unique resolutions: {(2816, 1880), (3504, 2336), (320, 211), (1600, 1216), (4752, 3168), (3456, 2304), (2496, 1664), (3264, 2448), (4272, 2848), (2560, 1920), (1920, 2560), (3008, 2000), (1444, 1444), (1620, 1444), (2196, 1957), (800, 533), (1792, 1184), (5184, 3456), (3888, 2592), (3072, 2048), (2500, 1666), (2048, 1536), (3088, 2056), (2592, 1944), (400, 315), (2124, 2056), (3215, 2136), (3872, 2592), (2544, 1696), (4928, 3264), (4288, 2848)}
